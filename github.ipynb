# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# GitHubからDL

# %%
import os

# トークンとユーザー情報を環境変数として設定
os.environ['GITHUB_AUTH'] = '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'  # トークンの実際の値に置き換えてください
os.environ['GITHUB_USER'] = 'yu37330'
os.environ['GITHUB_MAIL'] = 'yu37330@gmail.com'

# 環境変数としてリポジトリと作業ディレクトリを設定
os.environ['REPOSITORY'] = 'yu37330/colb-test'  # GitHubのリポジトリ名
os.environ['WORKDIR'] = '/content/drive/MyDrive/github/colb-test'  # 作業ディレクトリのパス
# 作業ディレクトリが既に存在している場合は、そのディレクトリをクリアまたは別の名前を使用します
# !rm -rf {os.environ['WORKDIR']}  # 既存のディレクトリを削除する場合
# !mkdir -p {os.environ['WORKDIR']}  # 作業ディレクトリを作成する
# !git clone https://github.com/{os.environ['REPOSITORY']}.git {os.environ['WORKDIR']}
# Out:
# Cloning into '/content/drive/MyDrive/github/colb-test'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 12 (delta 0), reused 3 (delta 0), pack-reused 0
# Receiving objects: 100% (12/12), done.

# %% [markdown]
# GitHubへプッシュ

# %%
# ユーザー情報を設定
# !git config --global user.email {os.environ['MAIL']}
# !git config --global user.name {os.environ['USER']}

# 作業ディレクトリに移動
# %cd {os.environ['WORKDIR']}

# ファイルの変更をステージング
# !git add hellocolab.py

# コミットメッセージを付けてコミット
# !git commit -m "TEST" #コミットメッセージをここに入力

# プッシュコマンドを実行
# !git push https://{os.environ['USER']}:{os.environ['ACCESS_TOKEN']}@github.com/yu37330/colb-test
# Out:
# /content/drive/MyDrive/github/colb-test
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/yu37330/colb-test/'
